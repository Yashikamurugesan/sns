# %% [markdown]
# # Relation Plot

# %% [raw]
# relplot has two kind type. They are
# Scatter plot
# line plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_data_home()
# Out:
# 'C:\\Users\\Asus\\seaborn-data'

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
taxis = sns.load_dataset('taxis')

# %%
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
taxis['payment'].unique()
# Out:
# array(['credit card', 'cash', nan], dtype=object)

# %%
taxis['tolls'].unique()
# Out:
# array([ 0.  ,  5.76, 12.5 ,  5.54,  8.4 , 17.28,  6.12,  2.64, 16.26,
#         9.5 , 11.52,  5.75, 24.02,  8.5 , 18.9 ,  4.75])

# %%
taxis['color'].unique()
# Out:
# array(['yellow', 'green'], dtype=object)

# %%
sns.relplot(x='total',y='tip',data=taxis)
plt.show()

# %%
sns.relplot(x='total',y='tip',data=taxis,kind='scatter')
plt.show()

# %%
sns.relplot(x='total',y='tip',data=taxis,size='total')
plt.show()

# %%
sns.relplot(x='total',y='tip',data=taxis,size='total',kind='scatter',hue='color',palette='crest')
plt.show()

# %%
sns.relplot(x='total',y='tip',data=taxis,hue='distance')
plt.show()

# %%
sns.relplot(x='total',y='tip',data=taxis,hue='color',style='color')

# %%
sns.relplot(x='total',y='tip',data=taxis,hue='color')

# %%
taxis.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
taxis[(taxis['pickup_zone'] == 'East New York') & (taxis['color'] == 'green')]
# Out:
#                    pickup              dropoff  passengers  distance   fare  \
# 5463  2019-03-22 14:56:45  2019-03-22 16:09:50           1     18.91  61.00
# 5467  2019-03-14 09:14:28  2019-03-14 09:39:12           1      4.47  16.39
# 5500  2019-03-04 08:59:17  2019-03-04 09:10:35           5      1.67   9.50
# 5521  2019-03-05 15:13:26  2019-03-05 15:48:56           1      6.10  28.00
# 6172  2019-03-13 09:04:25  2019-03-13 09:39:54           1      7.10  25.70
# 6284  2019-03-07 22:37:08  2019-03-07 23:17:15           1      8.43  33.50
# 6392  2019-03-30 09:36:30  2019-03-30 09:57:49           1      4.36  15.00
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.00
#
#        tip  tolls  total  color      payment    pickup_zone  \
# 5463  0.00   5.76  67.56  green  credit card  East New York
# 5467  0.00   0.00  16.89  green  credit card  East New York
# 5500  0.00   0.00  10.30  green  credit card  East New York
# ...

# %%
f1 = taxis["pickup_zone"]=="East New York"
f2 = taxis["color"]=='green'
  
taxis.where(f1 & f2, inplace = True)

# %%
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0                     NaN                  NaN         NaN       NaN   NaN
# 1                     NaN                  NaN         NaN       NaN   NaN
# 2                     NaN                  NaN         NaN       NaN   NaN
# 3                     NaN                  NaN         NaN       NaN   NaN
# 4                     NaN                  NaN         NaN       NaN   NaN
# ...                   ...                  ...         ...       ...   ...
# 6428                  NaN                  NaN         NaN       NaN   NaN
# 6429                  NaN                  NaN         NaN       NaN   NaN
# 6430                  NaN                  NaN         NaN       NaN   NaN
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29         1.0      1.12   6.0
# 6432                  NaN                  NaN         NaN       NaN   NaN
#
#       tip  tolls  total  color      payment    pickup_zone  \
# ...

# %% [markdown]
# # titanic

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset('titanic')

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
data['pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
sns.relplot(x='embark_town',y='fare',data=data)
plt.show()

# %%
sns.relplot(x='embark_town',y='fare',data=data,hue='class')

# %%
sns.relplot(x='embark_town',y='fare',data=data,hue='class',style='sex',palette='crest')

# %%
sns.relplot(x='embark_town',y='fare',data=data,hue='class',style='sex',palette='crest',size='deck')

# %%
sns.relplot(x='embark_town',y='fare',data=data,hue='class',style='sex',palette='crest',size='deck',kind='scatter')

# %%
sns.relplot(x='embark_town',y='fare',data=data,hue='class',style='sex',palette='crest',size='deck',kind='scatter')

# %%
sns.relplot(x='embark_town',y='fare',data=data,alpha=0.6)

# %%
fg = sns.relplot()
print(type(fg))
plot = sns.scatterplot()
print(type(plot))
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>
